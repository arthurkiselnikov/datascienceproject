# %%
import pandas as pd

# %%
vaxdist_df = pd.read_csv("COVID-19_Vaccinations_in_the_United_States_Jurisdiction.csv")
vaxdist_df
# Out:
#              Date  MMWR_week Location  Distributed  Distributed_Janssen  \
# 0      02/10/2022          6       DE      2160535                96000
# 1      02/10/2022          6       KS      5629435               253800
# 2      02/10/2022          6       ID      3156470               155300
# 3      02/10/2022          6       US    674675725             30209400
# 4      02/10/2022          6       WI     10856185               450400
# ...           ...        ...      ...          ...                  ...
# 27411  12/13/2020         51       AS         3900                    0
# 27412  12/13/2020         51      LTC            0                    0
# 27413  12/13/2020         51       VI          975                    0
# 27414  12/13/2020         51       US        13650                    0
# 27415  12/13/2020         51       GU         3900                    0
#
#        Distributed_Moderna  Distributed_Pfizer  Distributed_Unk_Manuf  \
# ...

# %%
Janssen_allo = pd.read_csv("COVID-19_Vaccine_Distribution_Allocations_by_Jurisdiction_-_Janssen.csv")
Janssen_allo
# Out:
#          Jurisdiction Week of Allocations  1st Dose Allocations
# 0         Connecticut          05/10/2021                  6400
# 1               Maine          05/10/2021                  2500
# 2       Massachusetts          05/10/2021                 12300
# 3       New Hampshire          05/10/2021                  2500
# 4        Rhode Island          05/10/2021                  2000
# ..                ...                 ...                   ...
# 499            Alaska          03/01/2021                  8900
# 500             Idaho          03/01/2021                 13300
# 501            Oregon          03/01/2021                 34400
# 502        Washington          03/01/2021                 60900
# 503  Federal Entities          03/01/2021                139200
#
# [504 rows x 3 columns]

# %%
Pfizer_allo = pd.read_csv("COVID-19_Vaccine_Distribution_Allocations_by_Jurisdiction_-_Pfizer.csv")
Pfizer_allo
# Out:
#        Jurisdiction Week of Allocations  1st Dose Allocations  \
# 0       Connecticut          06/21/2021                 54360
# 1             Maine          06/21/2021                 21420
# 2     Massachusetts          06/21/2021                104580
# 3     New Hampshire          06/21/2021                 21420
# 4      Rhode Island          06/21/2021                 17280
# ...             ...                 ...                   ...
# 1759       Virginia          12/14/2020                 72150
# 1760     Washington          12/14/2020                 62400
# 1761  West Virginia          12/14/2020                 16575
# 1762      Wisconsin          12/14/2020                 49725
# 1763        Wyoming          12/14/2020                  4875
#
#       2nd Dose Allocations
# 0                    54360
# 1                    21420
# 2                   104580
# 3                    21420
# 4                    17280
# ...                    ...
# ...

# %%
Moderna_allo = pd.read_csv("COVID-19_Vaccine_Distribution_Allocations_by_Jurisdiction_-_Moderna.csv")
Moderna_allo
# Out:
#        Jurisdiction Week of Allocations  1st Dose Allocations  \
# 0       Connecticut          06/21/2021                 41220
# 1             Maine          06/21/2021                 15800
# 2     Massachusetts          06/21/2021                 79500
# 3     New Hampshire          06/21/2021                 15800
# 4      Rhode Island          06/21/2021                 12480
# ...             ...                 ...                   ...
# 1696       Virginia          12/21/2020                146400
# 1697     Washington          12/21/2020                128000
# 1698  West Virginia          12/21/2020                 32600
# 1699      Wisconsin          12/21/2020                101000
# 1700        Wyoming          12/21/2020                 10000
#
#       2nd Dose Allocations
# 0                    41220
# 1                    15800
# 2                    79500
# 3                    15800
# 4                    12480
# ...                    ...
# ...
